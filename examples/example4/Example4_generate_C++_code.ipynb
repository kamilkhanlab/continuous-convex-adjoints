# %%
include("../src/ReverseADforVW.jl")

using .ReverseADforVW

# construct AD tape for function
nx = 1;
np = 300;
nf = 1;

# function has to be constructed as f(x,p,i) instead of f(p,x,i) or f(i,x,p), which will lead to error
# construct AD tape for function

function f(x, p, i)
    if i == 1
        f = sin(p[1]/2.0)*x[1]+sin(p[2]/2.0)*x[1]+sin(p[3]/2.0)*x[1]+sin(p[4]/2.0)*x[1]+sin(p[5]/2.0)*x[1]+sin(p[6]/2.0)*x[1]+sin(p[7]/2.0)*x[1]+sin(p[8]/2.0)*x[1]+sin(p[9]/2.0)*x[1]+sin(p[10]/2.0)*x[1]+sin(p[11]/2.0)*x[1]+sin(p[12]/2.0)*x[1]+sin(p[13]/2.0)*x[1]+sin(p[14]/2.0)*x[1]+sin(p[15]/2.0)*x[1]+sin(p[16]/2.0)*x[1]+sin(p[17]/2.0)*x[1]+sin(p[18]/2.0)*x[1]+sin(p[19]/2.0)*x[1]+sin(p[20]/2.0)*x[1]+sin(p[21]/2.0)*x[1]+sin(p[22]/2.0)*x[1]+sin(p[23]/2.0)*x[1]+sin(p[24]/2.0)*x[1]+sin(p[25]/2.0)*x[1]+sin(p[26]/2.0)*x[1]+sin(p[27]/2.0)*x[1]+sin(p[28]/2.0)*x[1]+sin(p[29]/2.0)*x[1]+sin(p[30]/2.0)*x[1]+sin(p[31]/2.0)*x[1]+sin(p[32]/2.0)*x[1]+sin(p[33]/2.0)*x[1]+sin(p[34]/2.0)*x[1]+sin(p[35]/2.0)*x[1]+sin(p[36]/2.0)*x[1]+sin(p[37]/2.0)*x[1]+sin(p[38]/2.0)*x[1]+sin(p[39]/2.0)*x[1]+sin(p[40]/2.0)*x[1]+sin(p[41]/2.0)*x[1]+sin(p[42]/2.0)*x[1]+sin(p[43]/2.0)*x[1]+sin(p[44]/2.0)*x[1]+sin(p[45]/2.0)*x[1]+sin(p[46]/2.0)*x[1]+sin(p[47]/2.0)*x[1]+sin(p[48]/2.0)*x[1]+sin(p[49]/2.0)*x[1]+sin(p[50]/2.0)*x[1]+sin(p[51]/2.0)*x[1]+sin(p[52]/2.0)*x[1]+sin(p[53]/2.0)*x[1]+sin(p[54]/2.0)*x[1]+sin(p[55]/2.0)*x[1]+sin(p[56]/2.0)*x[1]+sin(p[57]/2.0)*x[1]+sin(p[58]/2.0)*x[1]+sin(p[59]/2.0)*x[1]+sin(p[60]/2.0)*x[1]+sin(p[61]/2.0)*x[1]+sin(p[62]/2.0)*x[1]+sin(p[63]/2.0)*x[1]+sin(p[64]/2.0)*x[1]+sin(p[65]/2.0)*x[1]+sin(p[66]/2.0)*x[1]+sin(p[67]/2.0)*x[1]+sin(p[68]/2.0)*x[1]+sin(p[69]/2.0)*x[1]+sin(p[70]/2.0)*x[1]+sin(p[71]/2.0)*x[1]+sin(p[72]/2.0)*x[1]+sin(p[73]/2.0)*x[1]+sin(p[74]/2.0)*x[1]+sin(p[75]/2.0)*x[1]+sin(p[76]/2.0)*x[1]+sin(p[77]/2.0)*x[1]+sin(p[78]/2.0)*x[1]+sin(p[79]/2.0)*x[1]+sin(p[80]/2.0)*x[1]+sin(p[81]/2.0)*x[1]+sin(p[82]/2.0)*x[1]+sin(p[83]/2.0)*x[1]+sin(p[84]/2.0)*x[1]+sin(p[85]/2.0)*x[1]+sin(p[86]/2.0)*x[1]+sin(p[87]/2.0)*x[1]+sin(p[88]/2.0)*x[1]+sin(p[89]/2.0)*x[1]+sin(p[90]/2.0)*x[1]+sin(p[91]/2.0)*x[1]+sin(p[92]/2.0)*x[1]+sin(p[93]/2.0)*x[1]+sin(p[94]/2.0)*x[1]+sin(p[95]/2.0)*x[1]+sin(p[96]/2.0)*x[1]+sin(p[97]/2.0)*x[1]+sin(p[98]/2.0)*x[1]+sin(p[99]/2.0)*x[1]+sin(p[100]/2.0)*x[1]+sin(p[101]/2.0)*x[1]+sin(p[102]/2.0)*x[1]+sin(p[103]/2.0)*x[1]+sin(p[104]/2.0)*x[1]+sin(p[105]/2.0)*x[1]+sin(p[106]/2.0)*x[1]+sin(p[107]/2.0)*x[1]+sin(p[108]/2.0)*x[1]+sin(p[109]/2.0)*x[1]+sin(p[110]/2.0)*x[1]+sin(p[111]/2.0)*x[1]+sin(p[112]/2.0)*x[1]+sin(p[113]/2.0)*x[1]+sin(p[114]/2.0)*x[1]+sin(p[115]/2.0)*x[1]+sin(p[116]/2.0)*x[1]+sin(p[117]/2.0)*x[1]+sin(p[118]/2.0)*x[1]+sin(p[119]/2.0)*x[1]+sin(p[120]/2.0)*x[1]+sin(p[121]/2.0)*x[1]+sin(p[122]/2.0)*x[1]+sin(p[123]/2.0)*x[1]+sin(p[124]/2.0)*x[1]+sin(p[125]/2.0)*x[1]+sin(p[126]/2.0)*x[1]+sin(p[127]/2.0)*x[1]+sin(p[128]/2.0)*x[1]+sin(p[129]/2.0)*x[1]+sin(p[130]/2.0)*x[1]+sin(p[131]/2.0)*x[1]+sin(p[132]/2.0)*x[1]+sin(p[133]/2.0)*x[1]+sin(p[134]/2.0)*x[1]+sin(p[135]/2.0)*x[1]+sin(p[136]/2.0)*x[1]+sin(p[137]/2.0)*x[1]+sin(p[138]/2.0)*x[1]+sin(p[139]/2.0)*x[1]+sin(p[140]/2.0)*x[1]+sin(p[141]/2.0)*x[1]+sin(p[142]/2.0)*x[1]+sin(p[143]/2.0)*x[1]+sin(p[144]/2.0)*x[1]+sin(p[145]/2.0)*x[1]+sin(p[146]/2.0)*x[1]+sin(p[147]/2.0)*x[1]+sin(p[148]/2.0)*x[1]+sin(p[149]/2.0)*x[1]+sin(p[150]/2.0)*x[1]+sin(p[151]/2.0)*x[1]+sin(p[152]/2.0)*x[1]+sin(p[153]/2.0)*x[1]+sin(p[154]/2.0)*x[1]+sin(p[155]/2.0)*x[1]+sin(p[156]/2.0)*x[1]+sin(p[157]/2.0)*x[1]+sin(p[158]/2.0)*x[1]+sin(p[159]/2.0)*x[1]+sin(p[160]/2.0)*x[1]+sin(p[161]/2.0)*x[1]+sin(p[162]/2.0)*x[1]+sin(p[163]/2.0)*x[1]+sin(p[164]/2.0)*x[1]+sin(p[165]/2.0)*x[1]+sin(p[166]/2.0)*x[1]+sin(p[167]/2.0)*x[1]+sin(p[168]/2.0)*x[1]+sin(p[169]/2.0)*x[1]+sin(p[170]/2.0)*x[1]+sin(p[171]/2.0)*x[1]+sin(p[172]/2.0)*x[1]+sin(p[173]/2.0)*x[1]+sin(p[174]/2.0)*x[1]+sin(p[175]/2.0)*x[1]+sin(p[176]/2.0)*x[1]+sin(p[177]/2.0)*x[1]+sin(p[178]/2.0)*x[1]+sin(p[179]/2.0)*x[1]+sin(p[180]/2.0)*x[1]+sin(p[181]/2.0)*x[1]+sin(p[182]/2.0)*x[1]+sin(p[183]/2.0)*x[1]+sin(p[184]/2.0)*x[1]+sin(p[185]/2.0)*x[1]+sin(p[186]/2.0)*x[1]+sin(p[187]/2.0)*x[1]+sin(p[188]/2.0)*x[1]+sin(p[189]/2.0)*x[1]+sin(p[190]/2.0)*x[1]+sin(p[191]/2.0)*x[1]+sin(p[192]/2.0)*x[1]+sin(p[193]/2.0)*x[1]+sin(p[194]/2.0)*x[1]+sin(p[195]/2.0)*x[1]+sin(p[196]/2.0)*x[1]+sin(p[197]/2.0)*x[1]+sin(p[198]/2.0)*x[1]+sin(p[199]/2.0)*x[1]+sin(p[200]/2.0)*x[1]+sin(p[201]/2.0)*x[1]+sin(p[202]/2.0)*x[1]+sin(p[203]/2.0)*x[1]+sin(p[204]/2.0)*x[1]+sin(p[205]/2.0)*x[1]+sin(p[206]/2.0)*x[1]+sin(p[207]/2.0)*x[1]+sin(p[208]/2.0)*x[1]+sin(p[209]/2.0)*x[1]+sin(p[210]/2.0)*x[1]+sin(p[211]/2.0)*x[1]+sin(p[212]/2.0)*x[1]+sin(p[213]/2.0)*x[1]+sin(p[214]/2.0)*x[1]+sin(p[215]/2.0)*x[1]+sin(p[216]/2.0)*x[1]+sin(p[217]/2.0)*x[1]+sin(p[218]/2.0)*x[1]+sin(p[219]/2.0)*x[1]+sin(p[220]/2.0)*x[1]+sin(p[221]/2.0)*x[1]+sin(p[222]/2.0)*x[1]+sin(p[223]/2.0)*x[1]+sin(p[224]/2.0)*x[1]+sin(p[225]/2.0)*x[1]+sin(p[226]/2.0)*x[1]+sin(p[227]/2.0)*x[1]+sin(p[228]/2.0)*x[1]+sin(p[229]/2.0)*x[1]+sin(p[230]/2.0)*x[1]+sin(p[231]/2.0)*x[1]+sin(p[232]/2.0)*x[1]+sin(p[233]/2.0)*x[1]+sin(p[234]/2.0)*x[1]+sin(p[235]/2.0)*x[1]+sin(p[236]/2.0)*x[1]+sin(p[237]/2.0)*x[1]+sin(p[238]/2.0)*x[1]+sin(p[239]/2.0)*x[1]+sin(p[240]/2.0)*x[1]+sin(p[241]/2.0)*x[1]+sin(p[242]/2.0)*x[1]+sin(p[243]/2.0)*x[1]+sin(p[244]/2.0)*x[1]+sin(p[245]/2.0)*x[1]+sin(p[246]/2.0)*x[1]+sin(p[247]/2.0)*x[1]+sin(p[248]/2.0)*x[1]+sin(p[249]/2.0)*x[1]+sin(p[250]/2.0)*x[1]+sin(p[251]/2.0)*x[1]+sin(p[252]/2.0)*x[1]+sin(p[253]/2.0)*x[1]+sin(p[254]/2.0)*x[1]+sin(p[255]/2.0)*x[1]+sin(p[256]/2.0)*x[1]+sin(p[257]/2.0)*x[1]+sin(p[258]/2.0)*x[1]+sin(p[259]/2.0)*x[1]+sin(p[260]/2.0)*x[1]+sin(p[261]/2.0)*x[1]+sin(p[262]/2.0)*x[1]+sin(p[263]/2.0)*x[1]+sin(p[264]/2.0)*x[1]+sin(p[265]/2.0)*x[1]+sin(p[266]/2.0)*x[1]+sin(p[267]/2.0)*x[1]+sin(p[268]/2.0)*x[1]+sin(p[269]/2.0)*x[1]+sin(p[270]/2.0)*x[1]+sin(p[271]/2.0)*x[1]+sin(p[272]/2.0)*x[1]+sin(p[273]/2.0)*x[1]+sin(p[274]/2.0)*x[1]+sin(p[275]/2.0)*x[1]+sin(p[276]/2.0)*x[1]+sin(p[277]/2.0)*x[1]+sin(p[278]/2.0)*x[1]+sin(p[279]/2.0)*x[1]+sin(p[280]/2.0)*x[1]+sin(p[281]/2.0)*x[1]+sin(p[282]/2.0)*x[1]+sin(p[283]/2.0)*x[1]+sin(p[284]/2.0)*x[1]+sin(p[285]/2.0)*x[1]+sin(p[286]/2.0)*x[1]+sin(p[287]/2.0)*x[1]+sin(p[288]/2.0)*x[1]+sin(p[289]/2.0)*x[1]+sin(p[290]/2.0)*x[1]+sin(p[291]/2.0)*x[1]+sin(p[292]/2.0)*x[1]+sin(p[293]/2.0)*x[1]+sin(p[294]/2.0)*x[1]+sin(p[295]/2.0)*x[1]+sin(p[296]/2.0)*x[1]+sin(p[297]/2.0)*x[1]+sin(p[298]/2.0)*x[1]+sin(p[299]/2.0)*x[1]+sin(p[300]/2.0)*x[1]
    end
    
end

tape = record_tape(f,nx,np,1,nf) 

println(tape)
println("\nC++ code for Adjoint mode computation of subgradients of McCormick relaxations is generated for Example 4 as AdjointMC.cpp with its hearder file AdjointMC.hpp")
generate_revMC_c_code!(tape)
